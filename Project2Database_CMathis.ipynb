# %%
import pandas as pd
from pandas.io.json import json_normalize
import requests
import json
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
import MySQLdb
import mysql.connector

stationinfo_url = "https://gbfs.divvybikes.com/gbfs/en/station_information.json"
stationstatus_url = "https://gbfs.divvybikes.com/gbfs/en/station_status.json"

# Get country information in JSON format
divvy_stationinfo_response = requests.get(stationinfo_url).json()
divvy_stationstatus_response = requests.get(stationstatus_url).json()

# First element is general information, second is countries themselves
divvy_stationinfo_response = divvy_stationinfo_response["data"]["stations"]
divvy_stationstatus_response = divvy_stationstatus_response["data"]["stations"]

divvy_stationinfo_response
# Out:
# [{'station_id': '2',
#   'external_id': 'a3a36d9e-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Buckingham Fountain',
#   'short_name': '15541',
#   'lat': 41.87651122881695,
#   'lon': -87.62054800987242,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 39,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '3',
#   'external_id': 'a3a37378-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Shedd Aquarium',
#   'short_name': '15544',
#   'lat': 41.86722595682,
#   'lon': -87.6153553902,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 55,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '4',
#   'external_id': 'a3a378ca-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Burnham Harbor',
#   'short_name': '15545',
#   'lat': 41.856268,
#   'lon': -87.613348,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '5',
#   'external_id': 'a3a37e26-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'State St & Harrison St',
#   'short_name': 'SL-007',
#   'lat': 41.874053,
#   'lon': -87.627716,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '6',
#   'external_id': 'a3a38363-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Dusable Harbor',
#   'short_name': 'KA1503000064',
#   'lat': 41.886976,
#   'lon': -87.612813,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 39,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '7',
#   'external_id': 'a3a3888b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Field Blvd & South Water St',
#   'short_name': '15534',
#   'lat': 41.88634906269,
#   'lon': -87.6175165471,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '9',
#   'external_id': 'a3a39301-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Leavitt St & Archer Ave',
#   'short_name': 'KA1503000068',
#   'lat': 41.82879201994,
#   'lon': -87.6806044594,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '11',
#   'external_id': 'a3a3983e-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Jeffery Blvd & 71st St',
#   'short_name': 'KA1503000018',
#   'lat': 41.76663823695,
#   'lon': -87.5764501141,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '12',
#   'external_id': 'a3a39d55-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'South Shore Dr & 71st St',
#   'short_name': 'KA1503000002',
#   'lat': 41.7664094567,
#   'lon': -87.5656875719,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '13',
#   'external_id': 'a3a3a282-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wilton Ave & Diversey Pkwy',
#   'short_name': 'TA1306000014',
#   'lat': 41.932418,
#   'lon': -87.652705,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 35,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '14',
#   'external_id': 'a3a3a7b4-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Morgan St & 18th St',
#   'short_name': '13163',
#   'lat': 41.858086,
#   'lon': -87.651073,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '15',
#   'external_id': 'a3a3ace6-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Racine Ave & 18th St',
#   'short_name': '13164',
#   'lat': 41.858166,
#   'lon': -87.656495,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '16',
#   'external_id': 'a3a3b202-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Paulina Ave & North Ave',
#   'short_name': 'TA1305000037',
#   'lat': 41.910337,
#   'lon': -87.670072,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '17',
#   'external_id': 'a3a3b731-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Honore St & Division St',
#   'short_name': 'TA1305000034',
#   'lat': 41.903119,
#   'lon': -87.673935,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '18',
#   'external_id': 'a3a3bc53-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wacker Dr & Washington St',
#   'short_name': 'KA1503000072',
#   'lat': 41.883132,
#   'lon': -87.637321,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '19',
#   'external_id': 'a3a3c174-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Throop (Loomis) St & Taylor St',
#   'short_name': '13139',
#   'lat': 41.868968,
#   'lon': -87.659141,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '20',
#   'external_id': 'a3a3c696-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Sheffield Ave & Kingsbury St',
#   'short_name': '13154',
#   'lat': 41.910522,
#   'lon': -87.653106,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '21',
#   'external_id': 'a3a3cbac-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Aberdeen St & Jackson Blvd',
#   'short_name': '13157',
#   'lat': 41.87772613,
#   'lon': -87.65478743,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '22',
#   'external_id': 'a3a3d1b8-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'May St & Taylor St',
#   'short_name': '13160',
#   'lat': 41.8694821,
#   'lon': -87.6554864,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '23',
#   'external_id': 'a3a3d6f0-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Orleans St & Elm St',
#   'short_name': 'TA1306000006',
#   'lat': 41.902924,
#   'lon': -87.637715,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '24',
#   'external_id': 'a3a3dc37-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Fairbanks Ct & Grand Ave',
#   'short_name': 'TA1305000003',
#   'lat': 41.8925,
#   'lon': -87.6207,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '25',
#   'external_id': 'a3a3e158-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Michigan Ave & Pearson St',
#   'short_name': '13034',
#   'lat': 41.89766,
#   'lon': -87.62351,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '26',
#   'external_id': 'a3a3e67b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'McClurg Ct & Illinois St',
#   'short_name': 'TA1306000013',
#   'lat': 41.890359,
#   'lon': -87.617532,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 31,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '27',
#   'external_id': 'a3a3eb9a-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Larrabee St & North Ave',
#   'short_name': 'TA1306000008',
#   'lat': 41.91021,
#   'lon': -87.6435,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '28',
#   'external_id': 'a3a3f0c6-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Larrabee St & Menomonee St',
#   'short_name': 'TA1306000007',
#   'lat': 41.91468,
#   'lon': -87.64332,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '29',
#   'external_id': 'a3a3f5e9-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Noble St & Milwaukee Ave',
#   'short_name': '13290',
#   'lat': 41.90068,
#   'lon': -87.6626,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '30',
#   'external_id': 'a3a3fb5d-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Ashland Ave & Augusta Blvd',
#   'short_name': '13248',
#   'lat': 41.899643,
#   'lon': -87.6677,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '31',
#   'external_id': 'a3a40088-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Franklin St & Chicago Ave',
#   'short_name': '13017',
#   'lat': 41.896746973093805,
#   'lon': -87.63566762208939,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '32',
#   'external_id': 'a3a405a1-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Racine Ave & Congress Pkwy',
#   'short_name': 'TA1306000025',
#   'lat': 41.87464,
#   'lon': -87.65703,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '33',
#   'external_id': 'a3a40ad8-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'State St & Van Buren St',
#   'short_name': 'TA1305000035',
#   'lat': 41.877181,
#   'lon': -87.627844,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '34',
#   'external_id': 'a3a41004-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Cannon Dr & Fullerton Ave',
#   'short_name': '13124',
#   'lat': 41.9267559875,
#   'lon': -87.6344287848,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '35',
#   'external_id': 'a3a41526-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Streeter Dr & Grand Ave',
#   'short_name': '13022',
#   'lat': 41.892278,
#   'lon': -87.612043,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 47,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '36',
#   'external_id': 'a3a41af5-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Franklin St & Jackson Blvd',
#   'short_name': 'TA1305000025',
#   'lat': 41.8777079559,
#   'lon': -87.6353211408,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 39,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '37',
#   'external_id': 'a3a4203a-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Dearborn St & Adams St',
#   'short_name': 'TA1305000005',
#   'lat': 41.8793563587,
#   'lon': -87.6297910363,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '38',
#   'external_id': 'a3a42574-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clark St & Lake St',
#   'short_name': 'KA1503000012',
#   'lat': 41.88602082773,
#   'lon': -87.6308760584,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '39',
#   'external_id': 'a3a42a93-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wabash Ave & Adams St',
#   'short_name': 'KA1503000015',
#   'lat': 41.87947235235,
#   'lon': -87.6256886059,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '40',
#   'external_id': 'a3a42fa7-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'LaSalle St & Adams St',
#   'short_name': 'KA1503000034',
#   'lat': 41.87934437346,
#   'lon': -87.6319852213,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '41',
#   'external_id': 'a3a434ce-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Federal St & Polk St',
#   'short_name': 'SL-008',
#   'lat': 41.87207763285,
#   'lon': -87.6295437729,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '42',
#   'external_id': 'a3a43a25-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wabash Ave & Cermak Rd',
#   'short_name': 'TA1305000001',
#   'lat': 41.852619,
#   'lon': -87.626488,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '43',
#   'external_id': 'a3a43f48-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Michigan Ave & Washington St',
#   'short_name': '13001',
#   'lat': 41.8839840647265,
#   'lon': -87.6246839761734,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 43,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '44',
#   'external_id': 'a3a44476-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'State St & Randolph St',
#   'short_name': 'TA1305000029',
#   'lat': 41.8847302006,
#   'lon': -87.6277335692,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '45',
#   'external_id': 'a3a4499f-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Michigan Ave & Ida B Wells Dr',
#   'short_name': 'TA1305000010',
#   'lat': 41.876243,
#   'lon': -87.624426,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '46',
#   'external_id': 'a3a44ec7-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wells St & Walton St',
#   'short_name': 'TA1306000011',
#   'lat': 41.89993001,
#   'lon': -87.63443007,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '47',
#   'external_id': 'a3a453fa-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'State St & Kinzie St',
#   'short_name': '13050',
#   'lat': 41.889187,
#   'lon': -87.627754,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 31,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '48',
#   'external_id': 'a3a4591a-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Larrabee St & Kingsbury St',
#   'short_name': 'TA1306000009',
#   'lat': 41.897764,
#   'lon': -87.642884,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 43,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '49',
#   'external_id': 'a3a45e3b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Dearborn St & Monroe St',
#   'short_name': 'TA1305000006',
#   'lat': 41.881319815,
#   'lon': -87.6295209193,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 39,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '50',
#   'external_id': 'a3a46361-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clark St & Ida B Wells Dr',
#   'short_name': 'TA1305000009',
#   'lat': 41.8759326655,
#   'lon': -87.6305845355,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 35,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '51',
#   'external_id': 'a3a46896-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clark St & Randolph St',
#   'short_name': 'TA1305000030',
#   'lat': 41.884576228,
#   'lon': -87.63188991,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 39,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '52',
#   'external_id': 'a3a46e71-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Michigan Ave & Lake St',
#   'short_name': 'TA1305000011',
#   'lat': 41.886024,
#   'lon': -87.624117,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 35,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '53',
#   'external_id': 'a3a4739d-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wells St & Huron St',
#   'short_name': 'TA1306000012',
#   'lat': 41.894722,
#   'lon': -87.634362,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '54',
#   'external_id': 'a3a478c9-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Ogden Ave & Chicago Ave',
#   'short_name': 'TA1305000020',
#   'lat': 41.896362458,
#   'lon': -87.6540612729,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '55',
#   'external_id': 'a3a47dde-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Halsted St & Roosevelt Rd',
#   'short_name': 'TA1305000017',
#   'lat': 41.867324,
#   'lon': -87.648625,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '56',
#   'external_id': 'a3a482fb-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Desplaines St & Kinzie St',
#   'short_name': 'TA1306000003',
#   'lat': 41.888716036,
#   'lon': -87.6444478533,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '57',
#   'external_id': 'a3a4881d-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clinton St & Roosevelt Rd',
#   'short_name': 'WL-008',
#   'lat': 41.8671177825,
#   'lon': -87.6410879593,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '58',
#   'external_id': 'a3a48d5c-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Marshfield Ave & Cortland St',
#   'short_name': 'TA1305000039',
#   'lat': 41.916017,
#   'lon': -87.668879,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '59',
#   'external_id': 'a3a49288-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wabash Ave & Roosevelt Rd',
#   'short_name': 'TA1305000002',
#   'lat': 41.867227,
#   'lon': -87.625961,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '60',
#   'external_id': 'a3a497b6-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Dayton St & North Ave',
#   'short_name': '13058',
#   'lat': 41.9105780349,
#   'lon': -87.6494219288,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '61',
#   'external_id': 'a3a49cd7-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wood St & Milwaukee Ave',
#   'short_name': '13221',
#   'lat': 41.907655,
#   'lon': -87.672552,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '62',
#   'external_id': 'a3a4a202-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'McCormick Place',
#   'short_name': 'TA1305000004',
#   'lat': 41.8513751729,
#   'lon': -87.6188346489,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '66',
#   'external_id': 'a3a4a71e-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clinton St & Lake St',
#   'short_name': '13021',
#   'lat': 41.885637,
#   'lon': -87.641823,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '67',
#   'external_id': 'a3a4ac3f-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Sheffield Ave & Fullerton Ave',
#   'short_name': 'TA1306000016',
#   'lat': 41.9256018819,
#   'lon': -87.6537080423,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '68',
#   'external_id': 'a3a4b164-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clinton St & Tilden St',
#   'short_name': '13037',
#   'lat': 41.875885,
#   'lon': -87.640795,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '69',
#   'external_id': 'a3a4b693-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Damen Ave & Pierce Ave',
#   'short_name': 'TA1305000041',
#   'lat': 41.9093960065,
#   'lon': -87.6776919292,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '71',
#   'external_id': 'a3a4bbba-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Morgan St & Lake St',
#   'short_name': 'TA1306000015',
#   'lat': 41.8854833079,
#   'lon': -87.6523048564,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '72',
#   'external_id': 'a3a4c0df-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wabash Ave & 16th St',
#   'short_name': 'SL-012',
#   'lat': 41.860384,
#   'lon': -87.625813,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 39,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '73',
#   'external_id': 'a3a4c618-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Jefferson St & Monroe St',
#   'short_name': 'WL-011',
#   'lat': 41.880422,
#   'lon': -87.642746,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '74',
#   'external_id': 'a3a4cb42-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Kingsbury St & Erie St',
#   'short_name': '13265',
#   'lat': 41.89380805624359,
#   'lon': -87.64169722795485,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '75',
#   'external_id': 'a3a4d069-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Canal St & Jackson Blvd',
#   'short_name': '13138',
#   'lat': 41.877245,
#   'lon': -87.639366,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 47,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '76',
#   'external_id': 'a3a4d588-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Lake Shore Dr & Monroe St',
#   'short_name': '13300',
#   'lat': 41.880958,
#   'lon': -87.616743,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 39,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '77',
#   'external_id': 'a3a4daa1-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clinton St & Madison St',
#   'short_name': 'TA1305000032',
#   'lat': 41.882242,
#   'lon': -87.641066,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 31,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '80',
#   'external_id': 'a3a4e4e3-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Aberdeen St & Monroe St',
#   'short_name': '13156',
#   'lat': 41.880419,
#   'lon': -87.655519,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '81',
#   'external_id': 'a3a4ea00-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Daley Center Plaza',
#   'short_name': 'TA1306000010',
#   'lat': 41.884241,
#   'lon': -87.629634,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 39,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '84',
#   'external_id': 'a3a4ef26-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Milwaukee Ave & Grand Ave',
#   'short_name': '13033',
#   'lat': 41.891578,
#   'lon': -87.648384,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '85',
#   'external_id': 'a3a4f46b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Michigan Ave & Oak St',
#   'short_name': '13042',
#   'lat': 41.90096039,
#   'lon': -87.62377664,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '86',
#   'external_id': 'a3a4f993-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Eckhart Park',
#   'short_name': '13289',
#   'lat': 41.89637337,
#   'lon': -87.66098386,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '87',
#   'external_id': 'a3a4fec3-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Racine Ave & Fullerton Ave',
#   'short_name': 'TA1306000026',
#   'lat': 41.92556258,
#   'lon': -87.65840426,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '88',
#   'external_id': 'a3a503e5-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Racine Ave & Randolph St',
#   'short_name': '13155',
#   'lat': 41.884069,
#   'lon': -87.656853,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '89',
#   'external_id': 'a3a50991-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Financial Pl & Ida B Wells Dr',
#   'short_name': 'SL-010',
#   'lat': 41.8750236280333,
#   'lon': -87.6330940425396,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 31,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '90',
#   'external_id': 'a3a50ec8-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Millennium Park',
#   'short_name': '13008',
#   'lat': 41.8810317,
#   'lon': -87.62408432,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 47,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '91',
#   'external_id': 'a3a513e9-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clinton St & Washington Blvd',
#   'short_name': 'WL-012',
#   'lat': 41.88338,
#   'lon': -87.64117,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 31,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '92',
#   'external_id': 'a3a51934-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Carpenter St & Huron St',
#   'short_name': '13196',
#   'lat': 41.894556,
#   'lon': -87.653449,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '93',
#   'external_id': 'a3a51e6e-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Sheffield Ave & Willow St',
#   'short_name': 'TA1306000032',
#   'lat': 41.913688,
#   'lon': -87.652855,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '94',
#   'external_id': 'a3a523a6-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clark St & Armitage Ave',
#   'short_name': '13146',
#   'lat': 41.918306,
#   'lon': -87.636282,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 31,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '95',
#   'external_id': 'a3a528d0-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Stony Island Ave & 64th St',
#   'short_name': 'KA1503000021',
#   'lat': 41.778881,
#   'lon': -87.586647,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '96',
#   'external_id': 'a3a52df5-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Desplaines St & Randolph St',
#   'short_name': '15535',
#   'lat': 41.88461618962,
#   'lon': -87.6445705849,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '97',
#   'external_id': 'a3a53324-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Field Museum',
#   'short_name': '13029',
#   'lat': 41.865312,
#   'lon': -87.617867,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 55,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '98',
#   'external_id': 'a3a53843-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'LaSalle St & Washington St',
#   'short_name': '13006',
#   'lat': 41.882664,
#   'lon': -87.63253,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '99',
#   'external_id': 'a3a53d70-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Lake Shore Dr & Ohio St',
#   'short_name': 'TA1306000029',
#   'lat': 41.89257,
#   'lon': -87.614492,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '100',
#   'external_id': 'a3a5428e-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Orleans St & Merchandise Mart Plaza',
#   'short_name': 'TA1305000022',
#   'lat': 41.888243,
#   'lon': -87.63639,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 35,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '101',
#   'external_id': 'a3a547b8-a135-11e9-9cda-0a87ae2ba916',
#   'name': '63rd St Beach',
#   'short_name': '15491',
#   'lat': 41.78101637196,
#   'lon': -87.5761197602,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '102',
#   'external_id': 'a3a54cdb-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Stony Island Ave & 67th St',
#   'short_name': 'KA1503000023',
#   'lat': 41.77345849948,
#   'lon': -87.5853397391,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '103',
#   'external_id': 'a3a555e8-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clinton St & Polk St',
#   'short_name': '15542',
#   'lat': 41.87146651779,
#   'lon': -87.6409491327,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '106',
#   'external_id': 'a3a55b3e-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'State St & Pearson St',
#   'short_name': 'TA1307000061',
#   'lat': 41.897448,
#   'lon': -87.628722,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '107',
#   'external_id': 'a3a56075-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Desplaines St & Jackson Blvd',
#   'short_name': '15539',
#   'lat': 41.878287,
#   'lon': -87.643909,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '108',
#   'external_id': 'a3a565b1-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Halsted St & Polk St',
#   'short_name': 'TA1307000121',
#   'lat': 41.87184,
#   'lon': -87.64664,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '109',
#   'external_id': 'a3a56ae5-a135-11e9-9cda-0a87ae2ba916',
#   'name': '900 W Harrison St',
#   'short_name': '13028',
#   'lat': 41.874754,
#   'lon': -87.649807,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '110',
#   'external_id': 'a3a5700b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Dearborn St & Erie St',
#   'short_name': '13045',
#   'lat': 41.893992,
#   'lon': -87.629318,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '111',
#   'external_id': 'a3a57527-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Sedgwick St & Huron St',
#   'short_name': 'TA1307000062',
#   'lat': 41.894666,
#   'lon': -87.638437,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '112',
#   'external_id': 'a3a57a52-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Green St & Randolph St',
#   'short_name': '13053',
#   'lat': 41.883668,
#   'lon': -87.64867,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '113',
#   'external_id': 'a3a57f6b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Bissell St & Armitage Ave',
#   'short_name': '13059',
#   'lat': 41.91844,
#   'lon': -87.65222,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '114',
#   'external_id': 'a3a58495-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Sheffield Ave & Waveland Ave',
#   'short_name': 'TA1307000126',
#   'lat': 41.949399,
#   'lon': -87.654529,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '115',
#   'external_id': 'a3a589b9-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Sheffield Ave & Wellington Ave',
#   'short_name': 'TA1307000052',
#   'lat': 41.936266,
#   'lon': -87.652662,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '116',
#   'external_id': 'a3a58ee0-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Western Ave & Winnebago Ave',
#   'short_name': '13068',
#   'lat': 41.91552,
#   'lon': -87.687022,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '117',
#   'external_id': 'a3a593fc-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wilton Ave & Belmont Ave',
#   'short_name': 'TA1307000134',
#   'lat': 41.94018,
#   'lon': -87.65304,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 27,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '118',
#   'external_id': 'a3a59915-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Sedgwick St & North Ave',
#   'short_name': 'TA1307000038',
#   'lat': 41.911386,
#   'lon': -87.638677,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '119',
#   'external_id': 'a3a59ec3-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Ashland Ave & Lake St',
#   'short_name': '13073',
#   'lat': 41.88592,
#   'lon': -87.66717,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '120',
#   'external_id': 'a3a5a48b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wentworth Ave & Cermak Rd (Temp)',
#   'short_name': '13075',
#   'lat': 41.853005,
#   'lon': -87.630578,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '121',
#   'external_id': 'a3a5a9d0-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Blackstone Ave & Hyde Park Blvd',
#   'short_name': '13398',
#   'lat': 41.802562,
#   'lon': -87.590368,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '122',
#   'external_id': 'a3a5af44-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Ogden Ave & Congress Pkwy',
#   'short_name': '13081',
#   'lat': 41.87501,
#   'lon': -87.67328,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '123',
#   'external_id': 'a3a5b496-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'California Ave & Milwaukee Ave',
#   'short_name': '13084',
#   'lat': 41.922695,
#   'lon': -87.697153,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '124',
#   'external_id': 'a3a5b9d3-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Damen Ave & Cullerton St',
#   'short_name': '13089',
#   'lat': 41.855048,
#   'lon': -87.675726,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '125',
#   'external_id': 'a3a5bf01-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Rush St & Hubbard St',
#   'short_name': 'KA1503000044',
#   'lat': 41.890173,
#   'lon': -87.626185,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '126',
#   'external_id': 'a3a5c440-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clark St & North Ave',
#   'short_name': '13128',
#   'lat': 41.911974,
#   'lon': -87.631942,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '127',
#   'external_id': 'a3a5c96f-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Lincoln Ave & Fullerton Ave',
#   'short_name': 'TA1309000058',
#   'lat': 41.925905,
#   'lon': -87.64926,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '128',
#   'external_id': 'a3a5ce97-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Damen Ave & Chicago Ave',
#   'short_name': '13132',
#   'lat': 41.895769,
#   'lon': -87.67722,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '129',
#   'external_id': 'a3a5d3bb-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Blue Island Ave & 18th St',
#   'short_name': '13135',
#   'lat': 41.857556,
#   'lon': -87.661535,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '130',
#   'external_id': 'a3a5d8db-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Damen Ave & Division St',
#   'short_name': '13136',
#   'lat': 41.903266,
#   'lon': -87.678435,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '131',
#   'external_id': 'a3a5de24-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Lincoln Ave & Belmont Ave',
#   'short_name': 'TA1309000042',
#   'lat': 41.939365,
#   'lon': -87.668385,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '132',
#   'external_id': 'a3a5e353-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wentworth Ave & 24th St (Temp)',
#   'short_name': 'TA1308000026',
#   'lat': 41.85008369347577,
#   'lon': -87.6321405172348,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '133',
#   'external_id': 'a3a5eb69-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Kingsbury St & Kinzie St',
#   'short_name': 'KA1503000043',
#   'lat': 41.88917683258,
#   'lon': -87.6385057718,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 31,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '134',
#   'external_id': 'a3a5f0b8-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Peoria St & Jackson Blvd',
#   'short_name': '13158',
#   'lat': 41.8776415962753,
#   'lon': -87.64961779117584,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '135',
#   'external_id': 'a3a5f5e6-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Halsted St & 21st St',
#   'short_name': '13162',
#   'lat': 41.85378,
#   'lon': -87.64665,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '136',
#   'external_id': 'a3a5fb0d-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Racine Ave & 13th St',
#   'short_name': '13165',
#   'lat': 41.865054,
#   'lon': -87.656959,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '137',
#   'external_id': 'a3a6002c-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Morgan Ave & 14th Pl',
#   'short_name': 'TA1306000002',
#   'lat': 41.862378,
#   'lon': -87.651062,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '138',
#   'external_id': 'a3a6054c-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clybourn Ave & Division St',
#   'short_name': 'TA1307000115',
#   'lat': 41.904613,
#   'lon': -87.640552,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '140',
#   'external_id': 'a3a60a65-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Dearborn Pkwy & Delaware Pl',
#   'short_name': 'TA1307000128',
#   'lat': 41.898969,
#   'lon': -87.629912,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '141',
#   'external_id': 'a3a60f7e-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clark St & Lincoln Ave',
#   'short_name': '13179',
#   'lat': 41.915689,
#   'lon': -87.6346,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '142',
#   'external_id': 'a3a614ad-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'McClurg Ct & Erie St',
#   'short_name': 'KA1503000041',
#   'lat': 41.894503,
#   'lon': -87.617854,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 31,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '143',
#   'external_id': 'a3a61a0b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Sedgwick St & Webster Ave',
#   'short_name': '13191',
#   'lat': 41.922167,
#   'lon': -87.638888,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '144',
#   'external_id': 'a3a62025-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Larrabee St & Webster Ave',
#   'short_name': '13193',
#   'lat': 41.921822,
#   'lon': -87.64414,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '145',
#   'external_id': 'a3a62566-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Mies van der Rohe Way & Chestnut St',
#   'short_name': '15529',
#   'lat': 41.8985866514,
#   'lon': -87.6219152258,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
# ...
#   'external_id': 'a3b3686c-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'California Ave & Cortez St',
#   'short_name': '17660',
#   'lat': 41.900363,
#   'lon': -87.696704,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '623',
#   'external_id': 'a3b36d8a-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Michigan Ave & 8th St',
#   'short_name': '623',
#   'lat': 41.872773,
#   'lon': -87.623981,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 43,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '624',
#   'external_id': 'a3b372b1-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Dearborn St & Van Buren St',
#   'short_name': '624',
#   'lat': 41.876268,
#   'lon': -87.629155,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '625',
#   'external_id': 'a3b377cb-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Chicago Ave & Dempster St',
#   'short_name': 'E011',
#   'lat': 42.041691,
#   'lon': -87.680687,
#   'region_id': 35,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '626',
#   'external_id': 'a3b37ce0-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Delano Ct & Roosevelt Rd',
#   'short_name': 'KA1706005007',
#   'lat': 41.867491,
#   'lon': -87.63219,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '627',
#   'external_id': 'a3b3820c-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'LaSalle Dr & Huron St',
#   'short_name': 'KP1705001026',
#   'lat': 41.894877,
#   'lon': -87.632326,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '628',
#   'external_id': 'a3b38728-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Walsh Park',
#   'short_name': '18067',
#   'lat': 41.91461,
#   'lon': -87.667968,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '630',
#   'external_id': 'a3b38c3f-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Kildare Ave & Montrose Ave',
#   'short_name': 'KA1706005015',
#   'lat': 41.96108,
#   'lon': -87.73569,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '631',
#   'external_id': 'a3b3915a-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Malcolm X College',
#   'short_name': '631',
#   'lat': 41.877618,
#   'lon': -87.673895,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 19,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '632',
#   'external_id': 'a3b3968b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clark St & Newport St',
#   'short_name': '632',
#   'lat': 41.94454,
#   'lon': -87.654678,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '635',
#   'external_id': 'a3b39bb0-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Fairbanks St & Superior St',
#   'short_name': '18003',
#   'lat': 41.895748,
#   'lon': -87.620104,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '636',
#   'external_id': 'a3b3a0c8-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Orleans St & Hubbard St',
#   'short_name': '636',
#   'lat': 41.890028,
#   'lon': -87.636618,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '637',
#   'external_id': 'a3b419d9-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wood St & Chicago Ave (*)',
#   'short_name': '637',
#   'lat': 41.895634,
#   'lon': -87.672069,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 16,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '638',
#   'external_id': 'a3b41f78-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Clinton St & Jackson Blvd',
#   'short_name': '638',
#   'lat': 41.87811603010527,
#   'lon': -87.63983845710754,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 23,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '639',
#   'external_id': 'a3b424f6-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Lakefront Trail & Wilson Ave',
#   'short_name': '639',
#   'lat': 41.965845,
#   'lon': -87.645361,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '640',
#   'external_id': 'a3b42a3e-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Bernard St & Elston Ave',
#   'short_name': '18016',
#   'lat': 41.949923,
#   'lon': -87.713949,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '641',
#   'external_id': 'a3b42f5f-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Central Park Ave & Bloomingdale Ave',
#   'short_name': '18017',
#   'lat': 41.914166,
#   'lon': -87.716755,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '642',
#   'external_id': 'a3b43478-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Latrobe Ave & Chicago Ave',
#   'short_name': '642',
#   'lat': 41.894745,
#   'lon': -87.756895,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 7,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '643',
#   'external_id': 'a3b4399a-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Smith Park (*)',
#   'short_name': '643',
#   'lat': 41.892048,
#   'lon': -87.689397,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 16,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '644',
#   'external_id': 'a3b43eb7-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Western Ave & Fillmore St (*)',
#   'short_name': '644',
#   'lat': 41.868563,
#   'lon': -87.686234,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 12,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '645',
#   'external_id': 'a3b443ce-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Archer (Damen) Ave & 37th St',
#   'short_name': '18022',
#   'lat': 41.826712,
#   'lon': -87.683144,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '646',
#   'external_id': 'a3b4497a-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'State St & 54th St',
#   'short_name': '646',
#   'lat': 41.796642,
#   'lon': -87.625923,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '647',
#   'external_id': 'a3b44eba-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Elizabeth St & 59th St',
#   'short_name': '647',
#   'lat': 41.786691,
#   'lon': -87.655859,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 7,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '648',
#   'external_id': 'a3b453f2-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Carpenter St & 63rd St',
#   'short_name': '18025',
#   'lat': 41.77987,
#   'lon': -87.650919,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 7,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '649',
#   'external_id': 'a3b4590f-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Stewart Ave & 63rd St (*)',
#   'short_name': '649',
#   'lat': 41.779835,
#   'lon': -87.634774,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 12,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '650',
#   'external_id': 'a3b45e26-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Eggleston Ave & 69th St (*)',
#   'short_name': '650',
#   'lat': 41.768898,
#   'lon': -87.635876,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 12,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '651',
#   'external_id': 'a3b4633a-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Michigan Ave & 71st St',
#   'short_name': '651',
#   'lat': 41.765286,
#   'lon': -87.621748,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 7,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '652',
#   'external_id': 'a3b46866-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Rhodes Ave & 71st St',
#   'short_name': '652',
#   'lat': 41.766,
#   'lon': -87.611726,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '653',
#   'external_id': 'a3b46d7b-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Cornell Dr & Hayes Dr',
#   'short_name': '653',
#   'lat': 41.780595,
#   'lon': -87.584846,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '654',
#   'external_id': 'a3b4728f-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Racine Ave & Washington Blvd (*)',
#   'short_name': '654',
#   'lat': 41.883073,
#   'lon': -87.656952,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 12,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '655',
#   'external_id': 'a3b477ac-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Hoyne Ave & Balmoral Ave',
#   'short_name': '655',
#   'lat': 41.979851,
#   'lon': -87.681932,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '656',
#   'external_id': 'a3b47cbc-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Damen Ave & Walnut (Lake) St (*)',
#   'short_name': 'KA17018054',
#   'lat': 41.885951,
#   'lon': -87.677009,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 16,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '657',
#   'external_id': 'a3b481e1-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Wood St & Augusta Blvd',
#   'short_name': '657',
#   'lat': 41.899181,
#   'lon': -87.6722,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '658',
#   'external_id': 'a3b486f2-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Leavitt St & Division St (*)',
#   'short_name': '658',
#   'lat': 41.902997,
#   'lon': -87.683825,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 16,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '659',
#   'external_id': 'a3b48c07-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Leavitt St & Chicago Ave',
#   'short_name': '18058',
#   'lat': 41.895501,
#   'lon': -87.682017,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '660',
#   'external_id': 'a3b49122-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Sheridan Rd & Columbia Ave',
#   'short_name': '660',
#   'lat': 42.004583,
#   'lon': -87.661406,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '661',
#   'external_id': 'a3b4963f-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Evanston Civic Center',
#   'short_name': '661',
#   'lat': 42.057044,
#   'lon': -87.686554,
#   'region_id': 35,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '662',
#   'external_id': 'a3b49b4c-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Dodge Ave & Mulford St',
#   'short_name': '662',
#   'lat': 42.023463,
#   'lon': -87.699595,
#   'region_id': 35,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '663',
#   'external_id': 'a3b4a05c-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Lincolnwood Dr & Central St',
#   'short_name': 'E014',
#   'lat': 42.064854,
#   'lon': -87.715297,
#   'region_id': 35,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '664',
#   'external_id': 'a3b4a579-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Leavitt St & Belmont Ave (*)',
#   'short_name': 'KA17018068',
#   'lat': 41.939354,
#   'lon': -87.683282,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 16,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '665',
#   'external_id': 'a3b4aa91-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'South Chicago Ave & Elliot Ave',
#   'short_name': '665',
#   'lat': 41.747363,
#   'lon': -87.580046,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 7,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '666',
#   'external_id': 'a3b4afb6-a135-11e9-9cda-0a87ae2ba916',
#   'name': 'Cherry Ave & Blackhawk St',
#   'short_name': '18069',
#   'lat': 41.907221,
#   'lon': -87.655618,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 15,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '672',
#   'external_id': '8995498f-1209-4b06-9317-01cd695b3b61',
#   'name': 'Franklin St & Illinois St',
#   'short_name': 'RN-',
#   'lat': 41.89102331025185,
#   'lon': -87.63547986745834,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 11,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True},
#  {'station_id': '673',
#   'external_id': '9e1fbaaa-e872-4505-ada6-5080e62bef77',
#   'name': 'Lincoln Park Conservatory',
#   'short_name': 'LP-',
#   'lat': 41.92393131136619,
#   'lon': -87.63582453131676,
#   'rental_methods': ['CREDITCARD', 'TRANSITCARD', 'KEY'],
#   'capacity': 31,
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'has_kiosk': True}]

# %%
divvy_stationstatus_response
# Out:
# [{'station_id': '2',
#   'num_bikes_available': 14,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 25,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576181264,
#   'eightd_has_available_keys': False},
#  {'station_id': '3',
#   'num_bikes_available': 17,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 38,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202210,
#   'eightd_has_available_keys': False},
#  {'station_id': '4',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 23,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576185592,
#   'eightd_has_available_keys': False},
#  {'station_id': '5',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 18,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202803,
#   'eightd_has_available_keys': False},
#  {'station_id': '6',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 39,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576190321,
#   'eightd_has_available_keys': False},
#  {'station_id': '7',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199574,
#   'eightd_has_available_keys': False},
#  {'station_id': '9',
#   'num_bikes_available': 6,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 9,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576192927,
#   'eightd_has_available_keys': False},
#  {'station_id': '11',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 8,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576148419,
#   'eightd_has_available_keys': False},
#  {'station_id': '12',
#   'num_bikes_available': 4,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 11,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576187448,
#   'eightd_has_available_keys': False},
#  {'station_id': '13',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 27,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202225,
#   'eightd_has_available_keys': False},
#  {'station_id': '14',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 10,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576198265,
#   'eightd_has_available_keys': False},
#  {'station_id': '15',
#   'num_bikes_available': 13,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 2,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202521,
#   'eightd_has_available_keys': False},
#  {'station_id': '16',
#   'num_bikes_available': 6,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 9,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201046,
#   'eightd_has_available_keys': False},
#  {'station_id': '17',
#   'num_bikes_available': 4,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 19,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199547,
#   'eightd_has_available_keys': False},
#  {'station_id': '18',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 18,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576198756,
#   'eightd_has_available_keys': False},
#  {'station_id': '19',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 12,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576198345,
#   'eightd_has_available_keys': False},
#  {'station_id': '20',
#   'num_bikes_available': 12,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 3,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201441,
#   'eightd_has_available_keys': False},
#  {'station_id': '21',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199526,
#   'eightd_has_available_keys': False},
#  {'station_id': '22',
#   'num_bikes_available': 2,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 12,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200959,
#   'eightd_has_available_keys': False},
#  {'station_id': '23',
#   'num_bikes_available': 10,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 5,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199196,
#   'eightd_has_available_keys': False},
#  {'station_id': '24',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 15,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199896,
#   'eightd_has_available_keys': False},
#  {'station_id': '25',
#   'num_bikes_available': 16,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200807,
#   'eightd_has_available_keys': False},
#  {'station_id': '26',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 23,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202407,
#   'eightd_has_available_keys': False},
#  {'station_id': '27',
#   'num_bikes_available': 16,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 3,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1

#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 23,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200450,
#   'eightd_has_available_keys': False},
#  {'station_id': '76',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 2,
#   'num_docks_available': 30,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576193843,
#   'eightd_has_available_keys': False},
#  {'station_id': '77',
#   'num_bikes_available': 2,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 29,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202996,
#   'eightd_has_available_keys': False},
#  {'station_id': '80',
#   'num_bikes_available': 10,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 9,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202696,
#   'eightd_has_available_keys': False},
#  {'station_id': '81',
#   'num_bikes_available': 11,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 28,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202567,
#   'eightd_has_available_keys': False},
#  {'station_id': '84',
#   'num_bikes_available': 17,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 2,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200150,
#   'eightd_has_available_keys': False},
#  {'station_id': '85',
#   'num_bikes_available': 11,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 11,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200271,
#   'eightd_has_available_keys': False},
#  {'station_id': '86',
#   'num_bikes_available': 15,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 4,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200318,
#   'eightd_has_available_keys': False},
#  {'station_id': '87',
#   'num_bikes_available': 4,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201765,
#   'eightd_has_available_keys': False},
#  {'station_id': '88',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 16,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202688,
#   'eightd_has_available_keys': False},
#  {'station_id': '89',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 24,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199560,
#   'eightd_has_available_keys': False},
#  {'station_id': '90',
#   'num_bikes_available': 14,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 32,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202151,
#   'eightd_has_available_keys': False},
#  {'station_id': '91',
#   'num_bikes_available': 22,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 9,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201609,
#   'eightd_has_available_keys': False},
#  {'station_id': '92',
#   'num_bikes_available': 9,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 10,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576198859,
#   'eightd_has_available_keys': False},
#  {'station_id': '93',
#   'num_bikes_available': 13,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 2,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201916,
#   'eightd_has_available_keys': False},
#  {'station_id': '94',
#   'num_bikes_available': 15,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 16,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202867,
#   'eightd_has_available_keys': False},
#  {'station_id': '95',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 10,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576061958,
#   'eightd_has_available_keys': False},
#  {'station_id': '96',
#   'num_bikes_available': 2,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 21,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202772,
#   'eightd_has_available_keys': False},
#  {'station_id': '97',
#   'num_bikes_available': 19,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 36,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576194336,
#   'eightd_has_available_keys': False},
#  {'station_id': '98',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576193289,
#   'eightd_has_available_keys': False},
#  {'station_id': '99',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 12,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201846,
#   'eightd_has_available_keys': False},
#  {'station_id': '100',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 2,
#   'num_docks_available': 30,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202828,
#   'eightd_has_available_keys': False},
#  {'station_id': '101',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 8,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576092796,
#   'eightd_has_available_keys': False},
#  {'station_id': '102',
#   'num_bikes_available': 6,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 5,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576148066,
#   'eightd_has_available_keys': False},
#  {'station_id': '103',
#   'num_bikes_available': 10,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 5,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576198508,
#   'eightd_has_available_keys': False},
#  {'station_id': '106',
#   'num_bikes_available': 13,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200202,
#   'eightd_has_available_keys': False},
#  {'station_id': '107',
#   'num_bikes_available': 4,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 23,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202384,
#   'eightd_has_available_keys': False},
#  {'station_id': '108',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 11,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202359,
#   'eightd_has_available_keys': False},
#  {'station_id': '109',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 18,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199764,
#   'eightd_has_available_keys': False},
#  {'station_id': '110',
#   'num_bikes_available': 13,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202202,
#   'eightd_has_available_keys': False},
#  {'station_id': '111',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 22,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200033,
#   'eightd_has_available_keys': False},
#  {'station_id': '112',
#   'num_bikes_available': 14,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 1,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200920,
#   'eightd_has_available_keys': False},
#  {'station_id': '113',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202687,
#   'eightd_has_available_keys': False},
#  {'station_id': '114',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 22,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202319,
#   'eightd_has_available_keys': False},
#  {'station_id': '115',
#   'num_bikes_available': 9,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202464,
#   'eightd_has_available_keys': False},
#  {'station_id': '116',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 10,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201748,
#   'eightd_has_available_keys': False},
#  {'station_id': '117',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 27,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202979,
#   'eightd_has_available_keys': False},
#  {'station_id': '118',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 18,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201014,
#   'eightd_has_available_keys': False},
#  {'station_id': '119',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 18,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201727,
#   'eightd_has_available_keys': False},
#  {'station_id': '120',
#   'num_bikes_available': 9,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 10,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576193991,
#   'eightd_has_available_keys': False},
#  {'station_id': '121',
#   'num_bikes_available': 12,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 6,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576196915,
#   'eightd_has_available_keys': False},
#  {'station_id': '122',
#   'num_bikes_available': 2,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 13,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576

#   'num_bikes_available': 6,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 5,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200634,
#   'eightd_has_available_keys': False},
#  {'station_id': '172',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 4,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201737,
#   'eightd_has_available_keys': False},
#  {'station_id': '173',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 12,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201126,
#   'eightd_has_available_keys': False},
#  {'station_id': '174',
#   'num_bikes_available': 33,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 2,
#   'num_docks_available': 0,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200885,
#   'eightd_has_available_keys': False},
#  {'station_id': '175',
#   'num_bikes_available': 14,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 5,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199989,
#   'eightd_has_available_keys': False},
#  {'station_id': '176',
#   'num_bikes_available': 18,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 21,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202945,
#   'eightd_has_available_keys': False},
#  {'station_id': '177',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 28,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199445,
#   'eightd_has_available_keys': False},
#  {'station_id': '178',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202305,
#   'eightd_has_available_keys': False},
#  {'station_id': '179',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 8,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576177154,
#   'eightd_has_available_keys': False},
#  {'station_id': '180',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 10,
#   'num_docks_disabled': 0,
# ...
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202727,
#   'eightd_has_available_keys': False},
#  {'station_id': '599',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576126778,
#   'eightd_has_available_keys': False},
#  {'station_id': '600',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576203001,
#   'eightd_has_available_keys': False},
#  {'station_id': '601',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 15,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202801,
#   'eightd_has_available_keys': False},
#  {'station_id': '602',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202997,
#   'eightd_has_available_keys': False},
#  {'station_id': '603',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 10,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202871,
#   'eightd_has_available_keys': False},
#  {'station_id': '604',
#   'num_bikes_available': 4,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 11,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202839,
#   'eightd_has_available_keys': False},
#  {'station_id': '605',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202984,
#   'eightd_has_available_keys': False},
#  {'station_id': '619',
#   'num_bikes_available': 6,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 5,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576154586,
#   'eightd_has_available_keys': False},
#  {'station_id': '620',
#   'num_bikes_available': 2,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 13,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576201861,
#   'eightd_has_available_keys': False},
#  {'station_id': '621',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 15,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576195867,
#   'eightd_has_available_keys': False},
#  {'station_id': '622',
#   'num_bikes_available': 12,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 3,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200911,
#   'eightd_has_available_keys': False},
#  {'station_id': '623',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 42,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576194597,
#   'eightd_has_available_keys': False},
#  {'station_id': '624',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 10,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576198854,
#   'eightd_has_available_keys': False},
#  {'station_id': '625',
#   'num_bikes_available': 15,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 0,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202947,
#   'eightd_has_available_keys': False},
#  {'station_id': '626',
#   'num_bikes_available': 12,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202990,
#   'eightd_has_available_keys': False},
#  {'station_id': '627',
#   'num_bikes_available': 2,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 17,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576200420,
#   'eightd_has_available_keys': False},
#  {'station_id': '628',
#   'num_bikes_available': 9,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576196137,
#   'eightd_has_available_keys': False},
#  {'station_id': '630',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 14,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576187411,
#   'eightd_has_available_keys': False},
#  {'station_id': '631',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 11,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576195413,
#   'eightd_has_available_keys': False},
#  {'station_id': '632',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 8,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202783,
#   'eightd_has_available_keys': False},
#  {'station_id': '635',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 10,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576197751,
#   'eightd_has_available_keys': False},
#  {'station_id': '636',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 2,
#   'num_docks_available': 6,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199836,
#   'eightd_has_available_keys': False},
#  {'station_id': '637',
#   'num_bikes_available': 10,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 6,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202895,
#   'eightd_has_available_keys': False},
#  {'station_id': '638',
#   'num_bikes_available': 18,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 5,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576198691,
#   'eightd_has_available_keys': False},
#  {'station_id': '639',
#   'num_bikes_available': 0,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 15,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576193023,
#   'eightd_has_available_keys': False},
#  {'station_id': '640',
#   'num_bikes_available': 4,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202926,
#   'eightd_has_available_keys': False},
#  {'station_id': '641',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 8,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576126569,
#   'eightd_has_available_keys': False},
#  {'station_id': '642',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 6,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576061833,
#   'eightd_has_available_keys': False},
#  {'station_id': '643',
#   'num_bikes_available': 4,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 12,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202988,
#   'eightd_has_available_keys': False},
#  {'station_id': '644',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202792,
#   'eightd_has_available_keys': False},
#  {'station_id': '645',
#   'num_bikes_available': 4,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576198127,
#   'eightd_has_available_keys': False},
#  {'station_id': '646',
#   'num_bikes_available': 6,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 5,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576040224,
#   'eightd_has_available_keys': False},
#  {'station_id': '647',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 4,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576148317,
#   'eightd_has_available_keys': False},
#  {'station_id': '648',
#   'num_bikes_available': 4,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 3,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1575953921,
#   'eightd_has_available_keys': False},
#  {'station_id': '649',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 5,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1575867506,
#   'eightd_has_available_keys': False},
#  {'station_id': '650',
#   'num_bikes_available': 5,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 7,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574917169,
#   'eightd_has_available_keys': False},
#  {'station_id': '651',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 6,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1575953867,
#   'eightd_has_available_keys': False},
#  {'station_id': '652',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 3,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576112342,
#   'eightd_has_available_keys': False},
#  {'station_id': '653',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 3,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576061911,
#   'eightd_has_available_keys': False},
#  {'station_id': '654',
#   'num_bikes_available': 6,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 6,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202963,
#   'eightd_has_available_keys': False},
#  {'station_id': '655',
#   'num_bikes_available': 12,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 2,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202975,
#   'eightd_has_available_keys': False},
#  {'station_id': '656',
#   'num_bikes_available': 3,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 13,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202979,
#   'eightd_has_available_keys': False},
#  {'station_id': '657',
#   'num_bikes_available': 9,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 6,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576199625,
#   'eightd_has_available_keys': False},
#  {'station_id': '658',
#   'num_bikes_available': 2,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 13,
#   'num_docks_disabled': 1,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202942,
#   'eightd_has_available_keys': False},
#  {'station_id': '659',
#   'num_bikes_available': 2,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 13,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576197619,
#   'eightd_has_available_keys': False},
#  {'station_id': '660',
#   'num_bikes_available': 11,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 4,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576197837,
#   'eightd_has_available_keys': False},
#  {'station_id': '661',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 8,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576126706,
#   'eightd_has_available_keys': False},
#  {'station_id': '662',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 8,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202796,
#   'eightd_has_available_keys': False},
#  {'station_id': '663',
#   'num_bikes_available': 11,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 4,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202766,
#   'eightd_has_available_keys': False},
#  {'station_id': '664',
#   'num_bikes_available': 10,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 6,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202826,
#   'eightd_has_available_keys': False},
#  {'station_id': '665',
#   'num_bikes_available': 1,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 6,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576147846,
#   'eightd_has_available_keys': False},
#  {'station_id': '666',
#   'num_bikes_available': 7,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 8,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576192124,
#   'eightd_has_available_keys': False},
#  {'station_id': '672',
#   'num_bikes_available': 8,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 1,
#   'num_docks_available': 2,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202219,
#   'eightd_has_available_keys': False},
#  {'station_id': '673',
#   'num_bikes_available': 12,
#   'num_ebikes_available': 0,
#   'num_bikes_disabled': 0,
#   'num_docks_available': 19,
#   'num_docks_disabled': 0,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1576202676,
#   'eightd_has_available_keys': False}]

# %%
divvy_stationinfo_df = pd.DataFrame.from_dict(divvy_stationinfo_response, orient='columns')
divvy_stationinfo_df.reset_index(level=0, inplace=True)
clean_divvy_stationinfo_df = divvy_stationinfo_df.drop(["rental_methods"], axis = 1)
divvy_stationinfo_df.columns

clean_divvy_stationinfo_df
# Out:
#      index  capacity  eightd_has_key_dispenser  \
# 0        0        39                     False
# 1        1        55                     False
# 2        2        23                     False
# 3        3        23                     False
# 4        4        39                     False
# 5        5        19                     False
# 6        6        15                     False
# 7        7        11                     False
# 8        8        15                     False
# 9        9        35                     False
# 10      10        15                     False
# 11      11        15                     False
# 12      12        15                     False
# 13      13        23                     False
# 14      14        19                     False
# 15      15        15                     False
# 16      16        15                     False
# 17      17        23                     False
# 18      18        15                     False
# 19      19        15                     False
# 20      20        15                     False
# 21      21        23                     False
# 22      22        31                     False
# 23      23        19                     False
# 24      24        15                     False
# 25      25        15                     False
# 26      26        15                     False
# 27      27        23                     False
# 28      28        19                     False
# 29      29        27                     False
# ..     ...       ...                       ...
# 581    581        15                     False
# 582    582        11                     False
# 22        True  41.890359 -87.617532             McClurg Ct & Illinois St
# 23        True  41.910210 -87.643500              Larrabee St & North Ave
# 24        True  41.914680 -87.643320           Larrabee St & Menomonee St
# 25        True  41.900680 -87.662600             Noble St & Milwaukee Ave
# 26        True  41.899643 -87.667700           Ashland Ave & Augusta Blvd
# 27        True  41.896747 -87.635668            Franklin St & Chicago Ave
# 28        True  41.874640 -87.657030           Racine Ave & Congress Pkwy
# 29        True  41.877181 -87.627844              State St & Van Buren St
# ..         ...        ...        ...                                  ...
# 581       True  41.965845 -87.645361         Lakefront Trail & Wilson Ave
# 582       True  41.949923 -87.713949              Bernard St & Elston Ave
# 583       True  41.914166 -87.716755  Central Park Ave & Bloomingdale Ave
# 584       True  41.894745 -87.756895            Latrobe Ave & Chicago Ave
# 585       True  41.892048 -87.689397                       Smith Park (*)
# 586       True  41.868563 -87.686234        Western Ave & Fillmore St (*)
# 587       True  41.826712 -87.683144         Archer (Damen) Ave & 37th St
# 588       True  41.796642 -87.625923                   State St & 54th St
# 589       True  41.786691 -87.655859               Elizabeth St & 59th St
# 590       True  41.779870 -87.650919               Carpenter St & 63rd St
# 591       True  41.779835 -87.634774            Stewart Ave & 63rd St (*)
# 592       True  41.768898 -87.635876          Eggleston Ave & 69th St (*)
# 593       True  41.765286 -87.621748               Michigan Ave & 71st St
# 594       True  41.766000 -87.611726                 Rhodes Ave & 71st St
# 595       True  41.780595 -87.584846                Cornell Dr & Hayes Dr
# 596       True  41.883073 -87.656952     Racine Ave & Washington Blvd (*)
# 597       True  41.979851 -87.681932             Hoyne Ave & Balmoral Ave
# 598       True  41.885951 -87.677009     Damen Ave & Walnut (Lake) St (*)
# 599       True  41.899181 -87.672200               Wood St & Augusta Blvd
# 600       True  41.902997 -87.683825         Leavitt St & Division St (*)
# 601       True  41.895501 -87.682017             Leavitt St & Chicago Ave
# 602       True  42.004583 -87.661406           Sheridan Rd & Columbia Ave
# 603       True  42.057044 -87.686554                Evanston Civic Center
# 604       True  42.023463 -87.699595               Dodge Ave & Mulford St
# 605       True  42.064854 -87.715297          Lincolnwood Dr & Central St
# 606       True  41.939354 -87.683282         Leavitt St & Belmont Ave (*)
# 607       True  41.747363 -87.580046       South Chicago Ave & Elliot Ave
# 608       True  41.907221 -87.655618            Cherry Ave & Blackhawk St
# 609       True  41.891023 -87.635480            Franklin St & Illinois St
# 610       True  41.923931 -87.635825            Lincoln Park Conservatory
#
#      region_id    short_name station_id
# 0          NaN         15541          2
# 1          NaN         15544          3
# 2          NaN         15545          4
# 3          NaN        SL-007          5
# 4          NaN  KA1503000064          6
# 5          NaN         15534          7
# 6          NaN  KA1503000068          9
# 7          NaN  KA1503000018         11
# 8          NaN  KA1503000002         12
# 9          NaN  TA1306000014         13
# 10         NaN         13163         14
# 11         NaN         13164         15
# 12         NaN  TA1305000037         16
# 13         NaN  TA1305000034         17
# 14         NaN  KA1503000072         18
# 15         NaN         13139         19
# 16         NaN         13154         20
# 17         NaN         13157         21
# 18         NaN         13160         22
# 19         NaN  TA1306000006         23
# 20         NaN  TA1305000003         24
# 21         NaN         13034         25
# 22         NaN  TA1306000013         26
# 23         NaN  TA1306000008         27
# 24         NaN  TA1306000007         28
# 25         NaN         13290         29
# 26         NaN         13248         30
# 27         NaN         13017         31
# 28         NaN  TA1306000025         32
# 29         NaN  TA1305000035         33
# ..         ...           ...        ...
# 581        NaN           639        639
# 582        NaN         18016        640
# 583        NaN         18017        641
# 584        NaN           642        642
# 585        NaN           643        643
# 586        NaN           644        644
# 587        NaN         18022        645
# 588        NaN           646        646
# 589        NaN           647        647
# 590        NaN         18025        648
# 591        NaN           649        649
# 592        NaN           650        650
# 593        NaN           651        651
# 594        NaN           652        652
# 595        NaN           653        653
# 596        NaN           654        654
# 597        NaN           655        655
# 598        NaN    KA17018054        656
# 599        NaN           657        657
# 600        NaN           658        658
# 601        NaN         18058        659
# 602        NaN           660        660
# 603       35.0           661        661
# 604       35.0           662        662
# 605       35.0          E014        663
# 606        NaN    KA17018068        664
# 607        NaN           665        665
# 608        NaN         18069        666
# 609        NaN           RN-        672
# 610        NaN           LP-        673
#
# [611 rows x 12 columns]

# %%
divvy_stationstatus_df = pd.DataFrame.from_dict(divvy_stationstatus_response, orient='columns')
divvy_stationstatus_df.reset_index(level=0, inplace=True)
divvy_stationstatus_df.head()
# Out:
#    index  eightd_has_available_keys  is_installed  is_renting  is_returning  \
# 0      0                      False             1           1             1
# 1      1                      False             1           1             1
# 2      2                      False             1           1             1
# 3      3                      False             1           1             1
# 4      4                      False             1           1             1
#
#    last_reported  num_bikes_available  num_bikes_disabled  \
# 0     1576181264                   14                   0
# 1     1576202210                   17                   0
# 2     1576185592                    0                   0
# 3     1576202803                    5                   0
# 4     1576190321                    0                   0
#
#    num_docks_available  num_docks_disabled  num_ebikes_available station_id
# 0                   25                   0                     0          2
# 1                   38                   0                     0          3
# 2                   23                   0                     0          4
# 3                   18                   0                     0          5
# 4                   39                   0                     0          6

# %%
redfin_df = pd.read_csv("Redfin_Aug2019.csv")
redfin_df.head()
# Out:
#            City       Neighborhood        Lat        Lng   Month  Sale Price  \
# 0  Chicago, IL         Albany Park  41.968327 -87.728028  Aug-19       295.0
# 1  Chicago, IL       Andersonville  41.981658 -87.668476  Aug-19       419.0
# 2  Chicago, IL      Archer Heights  41.807900 -87.723585  Aug-19       226.0
# 3  Chicago, IL    Archer Highlands  41.878114 -87.629798  Aug-19       210.0
# 4  Chicago, IL       Armour Square  41.840755 -87.634019  Aug-19       265.0
#
#   Homes Sold New Listings  Days on Market
# 0        113          133              54
# 1         94           79              50
# 2         20           31              26
# 3          3            5              21
# 4          7           20              58

# %%
database_path = "Project2.db" #whatever you type in here will be the name of the database
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
inspector = inspect(engine)
inspector.get_table_names() #nice we just created our own db and its empty as it should be!
# Out:
# []

# %%
divvy_stationstatus_df.to_sql(name='divvy_stationstatus', con=engine, if_exists='replace', index=False)
clean_divvy_stationinfo_df.to_sql(name='divvy_stationinfo', con=engine, if_exists='replace', index=False)
redfin_df.to_sql(name='redfin_aug2019', con=engine, if_exists='replace', index=False)

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['divvy_stationinfo', 'divvy_stationstatus', 'redfin_aug2019']
